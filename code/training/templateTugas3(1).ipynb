# %% [markdown]
# Nama : Alif Rizky Excelsys Hanjono || NRP : 1151700031

# %%
# import library yang dibutuhkan

import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
import seaborn as sb
# %matplotlib inline

# %%
# !wget -O kc_house_data.csv https://raw.githubusercontent.com/franciscadias/data/master/kc_house_data.csv
# Out:
# --2019-10-21 02:50:09--  https://raw.githubusercontent.com/franciscadias/data/master/kc_house_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2515206 (2.4M) [text/plain]
# Saving to: ‘kc_house_data.csv’
#
# kc_house_data.csv   100%[===================>]   2.40M  --.-KB/s    in 0.09s
#
# 2019-10-21 02:50:14 (25.9 MB/s) - ‘kc_house_data.csv’ saved [2515206/2515206]

# %%
df = pd.read_csv("kc_house_data.csv")

df.tail()
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 21608   263000018  20140521T000000  ...           1530        1509
# 21609  6600060120  20150223T000000  ...           1830        7200
# 21610  1523300141  20140623T000000  ...           1020        2007
# 21611   291310100  20150116T000000  ...           1410        1287
# 21612  1523300157  20141015T000000  ...           1020        1357
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#                  id         price  ...  sqft_living15     sqft_lot15
# count  2.161300e+04  2.161300e+04  ...   21613.000000   21613.000000
# mean   4.580302e+09  5.400881e+05  ...    1986.552492   12768.455652
# std    2.876566e+09  3.671272e+05  ...     685.391304   27304.179631
# min    1.000102e+06  7.500000e+04  ...     399.000000     651.000000
# 25%    2.123049e+09  3.219500e+05  ...    1490.000000    5100.000000
# 50%    3.904930e+09  4.500000e+05  ...    1840.000000    7620.000000
# 75%    7.308900e+09  6.450000e+05  ...    2360.000000   10083.000000
# max    9.900000e+09  7.700000e+06  ...    6210.000000  871200.000000
#
# [8 rows x 20 columns]

# %%
cdf = df[['view','id','bedrooms','bathrooms']]
cdf.head(9)
# Out:
#    view          id  bedrooms  bathrooms
# 0     0  7129300520         3       1.00
# 1     0  6414100192         3       2.25
# 2     0  5631500400         2       1.00
# 3     0  2487200875         4       3.00
# 4     0  1954400510         3       2.00
# 5     0  7237550310         4       4.50
# 6     0  1321400060         3       2.25
# 7     0  2008000270         3       1.50
# 8     0  2414600126         3       1.00

# %%
viz = cdf[['view','id','bedrooms','bathrooms']]
viz.hist()
plt.show()

# %%
plt.scatter(cdf.view, cdf.id,  color='blue')
plt.xlabel("view")
plt.ylabel("id")
plt.show()

# %%
plt.scatter(cdf.bathrooms, cdf.id,  color='blue')
plt.xlabel("bathrooms")
plt.ylabel("id")
plt.show()

# %%
plt.scatter(train.view, train.bedrooms,  color='blue')
plt.xlabel("view")
plt.ylabel("bedrooms")
plt.show()

# %%
msk = np.random.rand(len(df)) < 0.8
train = cdf[msk]
test = cdf[~msk]

# %%
plt.scatter(train.view, train.bathrooms,  color='blue')
plt.xlabel("view")
plt.ylabel("bathrooms")
plt.show()

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
train_x = np.asanyarray(train[['view']])
train_y = np.asanyarray(train[['id']])
regr.fit (train_x, train_y)
# The coefficients
print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)
# Out:
# Coefficients:  [[50564677.98989895]]
# Intercept:  [4.56716103e+09]
