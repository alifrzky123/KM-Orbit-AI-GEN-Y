# %%
# !wget -O data.csv https://raw.githubusercontent.com/alifrzky123/belajar-orbit/2ee84609198903a9516e8a3ceda49590e8cc14d0/belajar_dataset/Transaction%20Burger%20Star1.csv
# Out:
# --2021-10-17 12:36:10--  https://raw.githubusercontent.com/alifrzky123/belajar-orbit/2ee84609198903a9516e8a3ceda49590e8cc14d0/belajar_dataset/Transaction%20Burger%20Star1.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 93906 (92K) [text/plain]
# Saving to: ‘data.csv’
#
# data.csv            100%[===================>]  91.71K  --.-KB/s    in 0.03s
#
# 2021-10-17 12:36:10 (3.37 MB/s) - ‘data.csv’ saved [93906/93906]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
#Reading Data From github
df = pd.read_csv('data.csv', delimiter =';')
df
# Out:
#      Timestamp           Type_Burger  ...  Gender   Payment
# 0        10:01           Beef burger  ...       1      DANA
# 1        10:04         Cheese burger  ...       0      DANA
# 2        10:05  Double cheese burger  ...       0  LINK AJA
# 3        10:06        Chicken burger  ...       0      DANA
# 4        10:07         Cheese burger  ...       1      DANA
# ...        ...                   ...  ...     ...       ...
# 2067     21:48           Beef burger  ...       0     TUNAI
# 2068     21:52           Beef burger  ...       1       OVO
# 2069     21:56  Double cheese burger  ...       0  LINK AJA
# 2070     22:00        Chicken burger  ...       1       OVO
# 2071     22:03           Beef burger  ...       1     TUNAI
#
# [2072 rows x 9 columns]

# %%
df['Timestamp']
# Out:
# 0       10:01
# 1       10:04
# 2       10:05
# 3       10:06
# 4       10:07
#         ...
# 2067    21:48
# 2068    21:52
# 2069    21:56
# 2070    22:00
# 2071    22:03
# Name: Timestamp, Length: 2072, dtype: object

# %%
df['Type_Burger'].value_counts()
# Out:
# Beef burger             577
# Chicken burger          567
# Double cheese burger    493
# Cheese burger           435
# Name: Type_Burger, dtype: int64

# %%
df['Type_Drink'].value_counts()
# Out:
# Mineral water    571
# None             543
# Coffe            491
# Coke             467
# Name: Type_Drink, dtype: int64

# %%
df.shape
# Out:
# (2072, 9)

# %%
df.columns
# Out:
# Index(['Timestamp', 'Type_Burger', 'Code_Burger', 'Amount_Burger',
#        'Type_Drink', 'Code_Drink', 'Amount_Drink', 'Gender', 'Payment'],
#       dtype='object')

# %%
from wordcloud import WordCloud

plt.rcParams['figure.figsize'] = (15, 15)
wordcloud = WordCloud(background_color = 'white', width = 1200,  height = 1200, max_words = 121).generate(str(df))
plt.imshow(wordcloud)
plt.axis('off')
plt.title('Most Popular Items',fontsize = 20)
plt.show()
