# %% [markdown]
# Nama :

# %%
# import library yang dibutuhkan

import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
import seaborn as sb
# %matplotlib inline

# %%
# !wget -O kc_house_data.csv https://raw.githubusercontent.com/franciscadias/data/master/kc_house_data.csv
# Out:
# --2019-10-15 09:55:58--  https://raw.githubusercontent.com/franciscadias/data/master/kc_house_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2515206 (2.4M) [text/plain]
# Saving to: ‘kc_house_data.csv’
#
# kc_house_data.csv   100%[===================>]   2.40M  --.-KB/s    in 0.03s
#
# 2019-10-15 09:55:58 (71.7 MB/s) - ‘kc_house_data.csv’ saved [2515206/2515206]
